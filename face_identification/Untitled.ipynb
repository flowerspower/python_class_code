# %%
from load_faces import read_jpg
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline


img = read_jpg('/notebook/faces/Sophia_Wang/IMG_1560.jpg')
img = img.mean(axis=2)

print img.shape
print img.size
#img[:,:,0] = 255

def makebrighter(image, howmuch):
    image += howmuch
    image = np.where(img>255, 255, img)
    return image

plt.figure(figsize=(5, 5))
print img
plt.imshow(img, cmap=plt.cm.gray) 
plt.figure(figsize=(5, 5))
newimage = makebrighter(img, 30)
print newimage
plt.imshow(newimage, cmap=plt.cm.gray) 

#plt.imshow(img[:,:,0], cmap=plt.cm.gray)
# Out:
# (640, 640)
# 409600
# [[ 253.          253.          253.         ...,  226.          226.          225.        ]
#  [ 253.          253.          253.         ...,  226.          226.          225.        ]
#  [ 253.          253.          253.         ...,  226.          225.          225.        ]
#  ...,
#  [  82.66666667   86.66666667   94.66666667 ...,   44.           45.           40.        ]
#  [  88.66666667   92.66666667   95.66666667 ...,   37.           38.           37.        ]
#  [  64.66666667   81.66666667   93.66666667 ...,   35.           39.           45.        ]]
# [[ 255.          255.          255.         ...,  255.          255.          255.        ]
#  [ 255.          255.          255.         ...,  255.          255.          255.        ]
#  [ 255.          255.          255.         ...,  255.          255.          255.        ]
#  ...,
#  [ 112.66666667  116.66666667  124.66666667 ...,   74.           75.           70.        ]
# ...
